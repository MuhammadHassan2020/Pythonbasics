# %% [markdown]
# **Python Exercises_week_2**

# %%
import numpy as np

# %%
my_list=[1,2,3,5,7]

# %%
my_list
# Out:
# [1, 2, 3, 5, 7]

# %%
my_list.append(11)

# %%
my_list #i run three times append thats why there are 3 11
# Out:
# [1, 2, 3, 5, 7, 11, 11, 11]

# %%
my_list[2]
# Out:
# 3

# %%
my_list_1=[3,7,9,10,11]
my_list_1[1]=2
my_list_1
# Out:
# [3, 2, 9, 10, 11]

# %%
my_fruits=['apple','banana','cherry']
my_fruits.pop()
my_fruits
# Out:
# ['apple', 'banana']

# %%
my_list2=[10, 20, 30, 40, 50]
my_list2[1:3]
# Out:
# [20, 30]

# %%
my_list3=[2, 4, 6, 8, 10]
my_list3[0:5:2]
# Out:
# [2, 6, 10]

# %%
for i in my_list3:
  print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
for i in range(len(my_list3)):   # this is the method we can target value index of list 'my_list[i] ye value dega' "range(len(my_list))" ye fn list ki min se maximum lenghth means 0 to 4 lega or loop chalega
  if i%2==0:
    print(f'index {my_list[i]}')
# Out:
# index 1
# index 3
# index 7

# %%
for i in range(len(my_list3)):   # this is the method we can target index of list 'i' ye index number dega
  if i%2==0:
    print(f'index {i}')
# Out:
# index 0
# index 2
# index 4

# %%
for i in range(len(my_list3)):   # this is the method we can target index of list
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
list_4=[1,2,3]+[2,3,4]
list_4
# Out:
# [1, 2, 3, 2, 3, 4]

# %%
list_5=['a', 'b', 'c', 'd', 'e', 'f']
list_5[3:7]
# Out:
# ['d', 'e', 'f']

# %%
list_5=['a', 'b', 'c', 'd', 'e', 'f']
list_5[-3:]
# Out:
# ['d', 'e', 'f']

# %%
select_list=[100, 200, 300, 400, 500, 600]
select_list[::2]   #this select every secon element
# Out:
# [100, 300, 500]

# %%
my_tuple= ('a', 'b', 'c')
my_Tlist= list(my_tuple)
my_Tlist
# Out:
# ['a', 'b', 'c']

# %%
my_dict = {"name": "Alice", "age": 25}

# %%
my_dict["city"] = "New York"  #how to add key and value pair in dictionary

# Output the updated dictionary
print(my_dict)
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'New York'}

# %%
Dictionary_1={"name":'Alice',"age":24}
Dictionary_2={"name":'bob','age':45}
merged_Dict=Dictionary_1.update(Dictionary_2)
Dictionary_1
# Out:
# {'name': 'bob', 'age': 45}

# %%
dict1 | dict2
