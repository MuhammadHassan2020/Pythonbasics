# %%
a = 'South bank'
a[1]
# Out:
# 'o'

# %%
a[-1]
# Out:
# 'k'

# %%
a[0:5]
# Out:
# 'South'

# %%
a[0:5:2]
# Out:
# 'Suh'

# %%
a[0:10:-2]
# Out:
# ''

# %%
print("hello world")
# Out:
# hello world

# %%
print(33)
# Out:
# 33

# %%
print("hello world \nHassan")
print("Hello world \n Hassan")
# Out:
# hello world
# Hassan
# Hello world
#  Hassan

# %%
print("I'm hungry")
# Out:
# I'm hungry

# %%
a
# Out:
# 'South bank'

# %%
a[0]
# Out:
# 'S'

# %%
a[0] = 's' #sting is Immutable its mean we cant change it
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-e3ba0c5e393e> in <cell line: 1>()
# ----> 1 a[0] = 's'
#
# TypeError: 'str' object does not support item assignment

# %%
b=a[1:] + 't'
b
# Out:
# 'outh bankt'

# %%
c=a + 't'
c
# Out:
# 'South bankt'

# %%
a= "MHassan"
b= "Abid"
c= a[1:]+" "+ b
c
# Out:
# 'Hassan Abid'

# %%
w="tegwtfTaimoor"
t= "uiuqiuAkber"
r = w[6:] +" "+ t[6:]
r
# Out:
# 'Taimoor Akber'

# %%
a= "MHassan"
b= "Abid"
c= b+" "+ a[1:]
c
# Out:
# 'Abid Hassan'

# %%
2+3
# Out:
# 5

# %%
'2'+'3'
# Out:
# '23'

# %%
't'*10
# Out:
# 'tttttttttt'

# %%
x= 'Hi student'
x.upper()
# Out:
# 'HI STUDENT'

# %%
x.lower()
# Out:
# 'hi student'

# %%
x.split()
# Out:
# ['Hi', 'student']

# %%
y='hassanabid' #it split where the space is
y.split()
# Out:
# ['hassanabid']

# %%
5.upper()
# Out:
#   File "<ipython-input-57-fdceb8c9b92e>", line 1
#     5.upper()
#      ^
# SyntaxError: invalid decimal literal

# %%
y='hassan,abid' #it split where the space is
y.split(',')
# Out:
# ['hassan', 'abid']

# %%
print('My name is {} and I am studying in {} of {}'.format('Hassan','LSBU','MSC APPLIEd AI') )
# Out:
# My name is Hassan and I am studying in LSBU of MSC APPLIEd AI

# %%
print('My name is {2} and I am studying in {0} of {1}'.format('LSBU','MSC APPLIEd AI','Hassan') )
# Out:
# My name is Hassan and I am studying in LSBU of MSC APPLIEd AI

# %%
print('the beautiful cat {} {} {} and {} {}'.format('Hair','Girl','Dark','cat','her'))
# Out:
# the beautiful cat Hair Girl Dark and cat her

# %%
print('the beautiful cat {a} {b} {c} and {d} {e}'.format(a='Hair',b='Girl',c='Dark',d='cat',e='her'))
# Out:
# the beautiful cat Hair Girl Dark and cat her

# %%
num=6/802
num
# Out:
# 0.007481296758104738

# %%
print('the result of dividing {} by {} is {} '.format(6,802,num))
# Out:
# the result of dividing 6 by 802 is 0.007481296758104738

# %%
print('the result of dividing {} by {} is {:1.3} '.format(6,802,num))
# Out:
# the result of dividing 6 by 802 is 0.00748

# %%
print('the result of dividing {} by {} is {:1.1} '.format(6,802,num))  #{:1,1} it mean 1 is for width and the second 1 which is used for how many value we need to precise after decimal point
# Out:
# the result of dividing 6 by 802 is 0.007

# %%
print('the result of dividing {} by {} is {:10.1} '.format(6,802,num))
# Out:
# the result of dividing 6 by 802 is      0.007

# %%
name= 'Ali'
job='scientist'
print ('My name is {}'.format(name))
# Out:
# My name is Ali

# %%
print(f'My name is {name}')
# Out:
# My name is Ali

# %%
our_list_1=[1,2,3]

# %%
our_list_2=['hello',34,our_list_1]
our_list_2
# Out:
# ['hello', 34, [1, 2, 3]]

# %%
our_list_2[0]
# Out:
# 'hello'

# %%
our_list_2[-1]
# Out:
# [1, 2, 3]

# %%
our_list_2[-1][1]    #from list2 it called the last element mean index -1 which is list_1 and after that it select index 1 which is 2
# Out:
# 2
