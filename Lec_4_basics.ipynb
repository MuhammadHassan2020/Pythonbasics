# %%
list_1=[1,2,3,4,5]
list_1.append('Hello')
list_1
# Out:
# [1, 2, 3, 4, 5, 'Hello']

# %%
list_1.pop()
# Out:
# 'Hello'

# %%
my_num=list_1.pop()
my_num
# Out:
# 'Hello'

# %%
list_2=['High']
value=list_1.pop(1)
list_2.append(value)
list_2
#list_2=['High']
# list_2.append(list_1.pop(1))
# list_2
# Out:
# ['High', 5]

# %%
list_a=['a','b','h','c','d']
list_b=[5,3,8,2]
list_a.sort()
list_a
# Out:
# ['a', 'b', 'c', 'd', 'h']

# %%
list_b.sort()

# %%
list_a
# Out:
# ['a', 'b', 'c', 'd', 'h']

# %%
list_a.reverse()

# %%
list_a
# Out:
# ['h', 'd', 'c', 'b', 'a']

# %%
dict_1 = {'key':(1,2,3,4,5)}

# %%
dict_1['key']
# Out:
# (1, 2, 3, 4, 5)

# %%
dict_2={'key1':(1,2,3,4,5,6),'key2':['a','b','c','d']}

# %%
dict_2['key1'][0]
# Out:
# 1

# %%
dict_2['key1'][3]
# Out:
# 4

# %%
dict_3={'key1':dict_1,'key2':dict_2}

# %%
dict_3
# Out:
# {'key1': {'key': (1, 2, 3, 4, 5)},
#  'key2': {'key1': (1, 2, 3, 4, 5, 6), 'key2': ['a', 'b', 'c', 'd']}}

# %%
dict_3['key1']
# Out:
# {'key': (1, 2, 3, 4, 5)}

# %%
dict_2['key2']
# Out:
# ['a', 'b', 'c', 'd']

# %%
dict_2['key2'][2]
# Out:
# 'c'

# %%
dict_2['key2'][2].upper()
# Out:
# 'C'

# %%
dict_2['key2']
# Out:
# ['a', 'b', 'c', 'd']

# %%
dict_2['key3']=['cpu','gpu']  #it adds the value in dict_2

# %%
dict_2
# Out:
# {'key1': (1, 2, 3, 4, 5, 6),
#  'key2': ['a', 'b', 'c', 'd'],
#  'key3': ['cpu', 'gpu']}

# %%
dict_2['key1']='bingo' #its update the value of 'key1'

# %%
dict_2
# Out:
# {'key1': 'bingo', 'key2': ['a', 'b', 'c', 'd'], 'key3': ['cpu', 'gpu']}

# %%
dict_2.keys()  #it call all the keys heading
# Out:
# dict_keys(['key1', 'key2', 'key3'])

# %%
dict_2.items()  #it gives value Key and value payer ('key',[value])
# Out:
# dict_items([('key1', 'bingo'), ('key2', ['a', 'b', 'c', 'd']), ('key3', ['cpu', 'gpu'])])

# %%
my_tuple=1,2,3 #its good idea to use paranthesis at the start and end ()

# %%
type(my_tuple)
# Out:
# tuple

# %%
my_tup=(1,2,3,3,4)  #create a tuple
my_list=[1,2,3,3,4]  #create a list

# %%
my_tup[0]
# Out:
# 1

# %%
my_list[0]
# Out:
# 1

# %%
my_list.index(1)     #it gives you the position of that number which is in the paranthesis
# Out:
# 0

# %%
my_tup.index(1)
# Out:
# 0

# %%
my_tup.count(3)      #it gives you the count of that number
# Out:
# 2

# %%
my_list.count(3)
# Out:
# 2

# %%
my_list[0]='adam'
my_list
# Out:
# ['adam', 2, 3, 3, 4]

# %%
my_tup[0]='adam'
my_tup                  #it gives error because tupple is immutable(not changable)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-5bda10775f88> in <cell line: 1>()
# ----> 1 my_tup[0]='adam'
#       2 my_tup
#
# TypeError: 'tuple' object does not support item assignment

# %%
my_set=set()

# %%
my_set.add('alpha')

# %%
my_set.add('2')

# %%
my_set.add(34)

# %%
my_set
# Out:
# {'2', 34, 'alpha'}

# %%
a_list=[3,3,3,3,5,5,5,5,8,8,8,8,]     #we need to find the unique value of list

# %%
new_set=set(a_list)                    # we use set() because its gives you unique number or element

# %%
new_set                                #here it is
# Out:
# {3, 5, 8}

# %%
#now make a list from set
new_list=list(new_set)

# %%
new_list
# Out:
# [8, 3, 5]

# %%
#BOOLEAN
4>8
# Out:
# False

# %%
if 4>8:
 print ('no')
